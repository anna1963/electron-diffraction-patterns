# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# training_datagen = ImageDataGenerator( rescale = 1.0/255.,
#                                    width_shift_range=0.2,
#                                    height_shift_range=0.2)
training_datagen = ImageDataGenerator(rescale = 1.0/255., zoom_range = 0.2)
validation_datagen  = ImageDataGenerator( rescale = 1.0/255.)
TRAINING_DIR = '/Users/anranxu/Desktop/ML/training'
VALIDATION_DIR = '/Users/anranxu/Desktop/ML/validation'
train_generator = training_datagen.flow_from_directory(
    TRAINING_DIR,
    target_size =(504,504),
    color_mode ='grayscale',
    class_mode ='categorical',
    batch_size = 32,
    save_to_dir = '/Users/anranxu/Desktop/augmented_data',
    save_format = 'jpg'
)
validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=(504,504),
    color_mode='grayscale',
    class_mode='categorical',
    batch_size= 32
)
# Out:
# Found 840 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(504,504,1)),
    tf.keras.layers.AveragePooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.AveragePooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.AveragePooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), 
    tf.keras.layers.Dense(10, activation='softmax')  
])

# %%
model.summary()

model.compile(loss = 'categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

history = model.fit(train_generator, epochs=125, steps_per_epoch=840//32, validation_data = validation_generator, verbose = 1, validation_steps=200//32)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 502, 502, 16)      160
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 251, 251, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 249, 249, 32)      4640
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 124, 124, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 122, 122, 64)      18496
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 61, 61, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 238144)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               121930240
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 121,958,666
# Trainable params: 121,958,666
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/125
# 26/26 [==============================] - 103s 4s/step - loss: 4.4237 - accuracy: 0.0668 - val_loss: 2.3027 - val_accuracy: 0.1042
# Epoch 2/125
# 26/26 [==============================] - 109s 4s/step - loss: 2.3089 - accuracy: 0.1077 - val_loss: 2.3027 - val_accuracy: 0.0990
# Epoch 3/125
# 26/26 [==============================] - 108s 4s/step - loss: 2.3128 - accuracy: 0.0928 - val_loss: 2.3049 - val_accuracy: 0.1042
# Epoch 4/125
# 26/26 [==============================] - 106s 4s/step - loss: 2.3068 - accuracy: 0.1027 - val_loss: 2.3064 - val_accuracy: 0.0938
# Epoch 5/125
# 26/26 [==============================] - 107s 4s/step - loss: 2.3246 - accuracy: 0.1052 - val_loss: 2.3044 - val_accuracy: 0.1042
# Epoch 6/125
# 26/26 [==============================] - 105s 4s/step - loss: 2.3065 - accuracy: 0.0965 - val_loss: 2.3027 - val_accuracy: 0.1042
# Epoch 7/125
# 26/26 [==============================] - 114s 4s/step - loss: 2.3090 - accuracy: 0.0829 - val_loss: 2.3028 - val_accuracy: 0.1042
# Epoch 8/125
# 26/26 [==============================] - 109s 4s/step - loss: 2.3216 - accuracy: 0.1070 - val_loss: 2.3032 - val_accuracy: 0.1042
# Epoch 9/125
# 26/26 [==============================] - 102s 4s/step - loss: 2.3061 - accuracy: 0.0982 - val_loss: 2.3513 - val_accuracy: 0.1042
# Epoch 10/125
# 26/26 [==============================] - 105s 4s/step - loss: 2.3663 - accuracy: 0.1058 - val_loss: 2.3027 - val_accuracy: 0.0990
# Epoch 11/125
# 26/26 [==============================] - 104s 4s/step - loss: 2.3034 - accuracy: 0.0941 - val_loss: 2.3028 - val_accuracy: 0.0990
# Epoch 12/125
# 26/26 [==============================] - 101s 4s/step - loss: 2.3304 - accuracy: 0.0855 - val_loss: 2.3030 - val_accuracy: 0.0938
# Epoch 13/125
# 26/26 [==============================] - 104s 4s/step - loss: 2.3062 - accuracy: 0.0792 - val_loss: 2.3028 - val_accuracy: 0.0990
# Epoch 14/125
# 26/26 [==============================] - 107s 4s/step - loss: 2.3043 - accuracy: 0.0842 - val_loss: 2.3266 - val_accuracy: 0.0990
# Epoch 15/125
# 26/26 [==============================] - 106s 4s/step - loss: 2.3109 - accuracy: 0.0817 - val_loss: 2.3028 - val_accuracy: 0.0990
# Epoch 16/125
# 26/26 [==============================] - 103s 4s/step - loss: 2.3256 - accuracy: 0.0995 - val_loss: 2.3034 - val_accuracy: 0.0990
# Epoch 17/125
# 26/26 [==============================] - 109s 4s/step - loss: 2.3037 - accuracy: 0.0925 - val_loss: 2.3030 - val_accuracy: 0.0938
# Epoch 18/125
# 26/26 [==============================] - 105s 4s/step - loss: 2.3053 - accuracy: 0.0855 - val_loss: 2.3027 - val_accuracy: 0.0990
# Epoch 19/125
# 26/26 [==============================] - 111s 4s/step - loss: 2.3052 - accuracy: 0.0986 - val_loss: 2.3030 - val_accuracy: 0.0990
# Epoch 20/125
# 26/26 [==============================] - 104s 4s/step - loss: 2.3033 - accuracy: 0.0880 - val_loss: 2.3028 - val_accuracy: 0.0938
# Epoch 21/125
# 26/26 [==============================] - 111s 4s/step - loss: 2.3679 - accuracy: 0.1058 - val_loss: 2.3032 - val_accuracy: 0.1042
# Epoch 22/125
# 26/26 [==============================] - 102s 4s/step - loss: 2.3071 - accuracy: 0.0804 - val_loss: 2.3032 - val_accuracy: 0.0990
# Epoch 23/125
# 26/26 [==============================] - 103s 4s/step - loss: 2.3046 - accuracy: 0.0854 - val_loss: 2.3036 - val_accuracy: 0.0990
# Epoch 24/125
# 26/26 [==============================] - 104s 4s/step - loss: 2.3033 - accuracy: 0.0965 - val_loss: 2.3048 - val_accuracy: 0.0990
# Epoch 25/125
# 26/26 [==============================] - 104s 4s/step - loss: 2.3368 - accuracy: 0.1077 - val_loss: 2.2896 - val_accuracy: 0.1927
# Epoch 26/125
# 26/26 [==============================] - 108s 4s/step - loss: 2.3005 - accuracy: 0.1378 - val_loss: 2.2624 - val_accuracy: 0.1927
# Epoch 27/125
# 26/26 [==============================] - 128s 5s/step - loss: 2.2609 - accuracy: 0.1659 - val_loss: 2.1722 - val_accuracy: 0.1979
# Epoch 28/125
# 26/26 [==============================] - 107s 4s/step - loss: 2.2247 - accuracy: 0.1856 - val_loss: 1.8898 - val_accuracy: 0.2917
# Epoch 29/125
# 26/26 [==============================] - 106s 4s/step - loss: 1.9102 - accuracy: 0.2475 - val_loss: 2.1159 - val_accuracy: 0.1094
# Epoch 30/125
# 26/26 [==============================] - 108s 4s/step - loss: 1.7288 - accuracy: 0.3007 - val_loss: 2.0694 - val_accuracy: 0.1875
# Epoch 31/125
# 26/26 [==============================] - 107s 4s/step - loss: 1.5960 - accuracy: 0.3626 - val_loss: 1.5549 - val_accuracy: 0.2604
# Epoch 32/125
# 26/26 [==============================] - 108s 4s/step - loss: 1.4502 - accuracy: 0.3985 - val_loss: 1.3235 - val_accuracy: 0.4844
# Epoch 33/125
# 26/26 [==============================] - 106s 4s/step - loss: 1.3887 - accuracy: 0.4022 - val_loss: 1.1316 - val_accuracy: 0.5938
# Epoch 34/125
# 26/26 [==============================] - 107s 4s/step - loss: 1.2914 - accuracy: 0.4423 - val_loss: 1.0815 - val_accuracy: 0.5052
# Epoch 35/125
# 26/26 [==============================] - 103s 4s/step - loss: 1.2772 - accuracy: 0.4209 - val_loss: 1.3004 - val_accuracy: 0.3750
# Epoch 36/125
# 26/26 [==============================] - 105s 4s/step - loss: 1.1735 - accuracy: 0.5012 - val_loss: 1.1464 - val_accuracy: 0.5521
# Epoch 37/125
# 26/26 [==============================] - 107s 4s/step - loss: 1.1958 - accuracy: 0.4760 - val_loss: 1.5064 - val_accuracy: 0.3698
# Epoch 38/125
# 26/26 [==============================] - 104s 4s/step - loss: 1.0562 - accuracy: 0.5599 - val_loss: 1.4353 - val_accuracy: 0.3021
# Epoch 39/125
# 26/26 [==============================] - 107s 4s/step - loss: 1.2634 - accuracy: 0.4724 - val_loss: 0.8625 - val_accuracy: 0.6198
# Epoch 40/125
# 26/26 [==============================] - 103s 4s/step - loss: 1.0580 - accuracy: 0.5217 - val_loss: 1.6540 - val_accuracy: 0.1458
# Epoch 41/125
# 26/26 [==============================] - 108s 4s/step - loss: 1.1578 - accuracy: 0.4976 - val_loss: 1.1499 - val_accuracy: 0.5260
# Epoch 42/125
# 26/26 [==============================] - 107s 4s/step - loss: 0.9470 - accuracy: 0.5941 - val_loss: 1.4707 - val_accuracy: 0.3229
# Epoch 43/125
# 26/26 [==============================] - 113s 4s/step - loss: 1.0720 - accuracy: 0.5421 - val_loss: 0.8508 - val_accuracy: 0.6979
# Epoch 44/125
# 26/26 [==============================] - 115s 4s/step - loss: 0.9491 - accuracy: 0.5925 - val_loss: 0.9216 - val_accuracy: 0.5729
# Epoch 45/125
# 26/26 [==============================] - 108s 4s/step - loss: 0.9163 - accuracy: 0.5928 - val_loss: 0.8761 - val_accuracy: 0.5469
# Epoch 46/125
# 26/26 [==============================] - 117s 4s/step - loss: 0.8329 - accuracy: 0.6399 - val_loss: 0.6158 - val_accuracy: 0.6927
# Epoch 47/125
# 26/26 [==============================] - 106s 4s/step - loss: 0.9562 - accuracy: 0.6097 - val_loss: 1.0862 - val_accuracy: 0.4062
# Epoch 48/125
# 26/26 [==============================] - 111s 4s/step - loss: 0.8805 - accuracy: 0.5941 - val_loss: 0.5750 - val_accuracy: 0.7135
# Epoch 49/125
# 26/26 [==============================] - 130s 5s/step - loss: 0.8259 - accuracy: 0.6046 - val_loss: 0.7798 - val_accuracy: 0.6510
# Epoch 50/125
# 26/26 [==============================] - 117s 5s/step - loss: 0.7397 - accuracy: 0.6993 - val_loss: 0.5808 - val_accuracy: 0.7083
# Epoch 51/125
# 26/26 [==============================] - 123s 5s/step - loss: 0.8073 - accuracy: 0.7191 - val_loss: 0.7682 - val_accuracy: 0.6146
# Epoch 52/125
# 26/26 [==============================] - 116s 4s/step - loss: 0.7085 - accuracy: 0.6943 - val_loss: 0.6174 - val_accuracy: 0.6615
# Epoch 53/125
# 26/26 [==============================] - 120s 5s/step - loss: 0.8516 - accuracy: 0.6349 - val_loss: 0.4711 - val_accuracy: 0.7969
# Epoch 54/125
# 26/26 [==============================] - 127s 5s/step - loss: 0.6849 - accuracy: 0.6658 - val_loss: 0.5442 - val_accuracy: 0.7969
# Epoch 55/125
# 26/26 [==============================] - 115s 4s/step - loss: 0.7470 - accuracy: 0.6621 - val_loss: 0.7693 - val_accuracy: 0.6823
# Epoch 56/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.8041 - accuracy: 0.6077 - val_loss: 0.5006 - val_accuracy: 0.8698
# Epoch 57/125
# 26/26 [==============================] - 114s 4s/step - loss: 0.7457 - accuracy: 0.7296 - val_loss: 0.6626 - val_accuracy: 0.7240
# Epoch 58/125
# 26/26 [==============================] - 109s 4s/step - loss: 0.6751 - accuracy: 0.7015 - val_loss: 0.6453 - val_accuracy: 0.7812
# Epoch 59/125
# 26/26 [==============================] - 129s 5s/step - loss: 0.7310 - accuracy: 0.6300 - val_loss: 0.5568 - val_accuracy: 0.7292
# Epoch 60/125
# 26/26 [==============================] - 123s 5s/step - loss: 0.7434 - accuracy: 0.6856 - val_loss: 0.5155 - val_accuracy: 0.7552
# Epoch 61/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.7120 - accuracy: 0.6782 - val_loss: 1.1487 - val_accuracy: 0.6094
# Epoch 62/125
# 26/26 [==============================] - 115s 4s/step - loss: 0.7802 - accuracy: 0.6755 - val_loss: 0.4096 - val_accuracy: 0.8177
# Epoch 63/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.6095 - accuracy: 0.7411 - val_loss: 0.3353 - val_accuracy: 0.9010
# Epoch 64/125
# 26/26 [==============================] - 114s 4s/step - loss: 0.6126 - accuracy: 0.7608 - val_loss: 0.5583 - val_accuracy: 0.7448
# Epoch 65/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.6757 - accuracy: 0.6862 - val_loss: 1.3530 - val_accuracy: 0.3177
# Epoch 66/125
# 26/26 [==============================] - 113s 4s/step - loss: 0.6316 - accuracy: 0.7092 - val_loss: 0.4765 - val_accuracy: 0.7240
# Epoch 67/125
# 26/26 [==============================] - 114s 4s/step - loss: 0.5631 - accuracy: 0.7392 - val_loss: 0.4156 - val_accuracy: 0.8698
# Epoch 68/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.5824 - accuracy: 0.7649 - val_loss: 0.6482 - val_accuracy: 0.6615
# Epoch 69/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.8942 - accuracy: 0.6977 - val_loss: 0.7615 - val_accuracy: 0.6146
# Epoch 70/125
# 26/26 [==============================] - 114s 4s/step - loss: 0.3874 - accuracy: 0.8558 - val_loss: 0.2774 - val_accuracy: 0.9479
# Epoch 71/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.6335 - accuracy: 0.7105 - val_loss: 0.5112 - val_accuracy: 0.7865
# Epoch 72/125
# 26/26 [==============================] - 114s 4s/step - loss: 0.5301 - accuracy: 0.7668 - val_loss: 0.2581 - val_accuracy: 0.9844
# Epoch 73/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.5629 - accuracy: 0.8045 - val_loss: 0.4905 - val_accuracy: 0.7500
# Epoch 74/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.5116 - accuracy: 0.8168 - val_loss: 0.2928 - val_accuracy: 0.9219
# Epoch 75/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.5155 - accuracy: 0.7550 - val_loss: 0.2837 - val_accuracy: 0.9115
# Epoch 76/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.7078 - accuracy: 0.7436 - val_loss: 0.2543 - val_accuracy: 0.9844
# Epoch 77/125
# 26/26 [==============================] - 114s 4s/step - loss: 0.3899 - accuracy: 0.8353 - val_loss: 0.4750 - val_accuracy: 0.7448
# Epoch 78/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.5192 - accuracy: 0.8045 - val_loss: 0.8103 - val_accuracy: 0.5573
# Epoch 79/125
# 26/26 [==============================] - 111s 4s/step - loss: 0.4692 - accuracy: 0.8230 - val_loss: 0.3627 - val_accuracy: 0.8177
# Epoch 80/125
# 26/26 [==============================] - 111s 4s/step - loss: 0.6353 - accuracy: 0.7599 - val_loss: 0.4059 - val_accuracy: 0.9115
# Epoch 81/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.6238 - accuracy: 0.7426 - val_loss: 0.3051 - val_accuracy: 0.9531
# Epoch 82/125
# 26/26 [==============================] - 108s 4s/step - loss: 0.5216 - accuracy: 0.8267 - val_loss: 9.4673 - val_accuracy: 0.3646
# Epoch 83/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.6367 - accuracy: 0.9307 - val_loss: 0.2808 - val_accuracy: 0.8542
# Epoch 84/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.6150 - accuracy: 0.7636 - val_loss: 1.2405 - val_accuracy: 0.4219
# Epoch 85/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.5370 - accuracy: 0.7550 - val_loss: 2.2573 - val_accuracy: 0.3073
# Epoch 86/125
# 26/26 [==============================] - 115s 4s/step - loss: 0.5358 - accuracy: 0.7983 - val_loss: 0.6594 - val_accuracy: 0.7344
# Epoch 87/125
# 26/26 [==============================] - 115s 4s/step - loss: 0.4672 - accuracy: 0.8017 - val_loss: 0.3759 - val_accuracy: 0.8229
# Epoch 88/125
# 26/26 [==============================] - 123s 5s/step - loss: 0.4379 - accuracy: 0.8601 - val_loss: 0.3108 - val_accuracy: 0.8750
# Epoch 89/125
# 26/26 [==============================] - 117s 4s/step - loss: 0.5605 - accuracy: 0.7704 - val_loss: 0.5890 - val_accuracy: 0.7656
# Epoch 90/125
# 26/26 [==============================] - 125s 5s/step - loss: 0.4130 - accuracy: 0.8255 - val_loss: 0.7797 - val_accuracy: 0.6354
# Epoch 91/125
# 26/26 [==============================] - 150s 6s/step - loss: 0.3880 - accuracy: 0.8377 - val_loss: 2.5280 - val_accuracy: 0.5365
# Epoch 92/125
# 26/26 [==============================] - 120s 5s/step - loss: 0.5398 - accuracy: 0.8163 - val_loss: 0.9431 - val_accuracy: 0.5052
# Epoch 93/125
# 26/26 [==============================] - 123s 5s/step - loss: 0.5176 - accuracy: 0.7797 - val_loss: 0.1806 - val_accuracy: 0.9427
# Epoch 94/125
# 26/26 [==============================] - 111s 4s/step - loss: 0.4502 - accuracy: 0.8329 - val_loss: 0.3264 - val_accuracy: 0.8490
# Epoch 95/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.3780 - accuracy: 0.8425 - val_loss: 0.3290 - val_accuracy: 0.8594
# Epoch 96/125
# 26/26 [==============================] - 109s 4s/step - loss: 0.4532 - accuracy: 0.8354 - val_loss: 0.4992 - val_accuracy: 0.7344
# Epoch 97/125
# 26/26 [==============================] - 109s 4s/step - loss: 0.5786 - accuracy: 0.7822 - val_loss: 0.2833 - val_accuracy: 0.9375
# Epoch 98/125
# 26/26 [==============================] - 109s 4s/step - loss: 0.5077 - accuracy: 0.7859 - val_loss: 0.2676 - val_accuracy: 0.9271
# Epoch 99/125
# 26/26 [==============================] - 108s 4s/step - loss: 0.6491 - accuracy: 0.7599 - val_loss: 0.1859 - val_accuracy: 0.9844
# Epoch 100/125
# 26/26 [==============================] - 111s 4s/step - loss: 0.4333 - accuracy: 0.8725 - val_loss: 0.2654 - val_accuracy: 0.9479
# Epoch 101/125
# 26/26 [==============================] - 111s 4s/step - loss: 0.4462 - accuracy: 0.8540 - val_loss: 0.3614 - val_accuracy: 0.8125
# Epoch 102/125
# 26/26 [==============================] - 117s 4s/step - loss: 0.6453 - accuracy: 0.7538 - val_loss: 0.2347 - val_accuracy: 0.9479
# Epoch 103/125
# 26/26 [==============================] - 119s 5s/step - loss: 0.5709 - accuracy: 0.7392 - val_loss: 0.2903 - val_accuracy: 0.8854
# Epoch 104/125
# 26/26 [==============================] - 119s 5s/step - loss: 0.5064 - accuracy: 0.7822 - val_loss: 0.1897 - val_accuracy: 0.9740
# Epoch 105/125
# 26/26 [==============================] - 120s 5s/step - loss: 0.4123 - accuracy: 0.8304 - val_loss: 0.6610 - val_accuracy: 0.6823
# Epoch 106/125
# 26/26 [==============================] - 128s 5s/step - loss: 0.4216 - accuracy: 0.8245 - val_loss: 0.1701 - val_accuracy: 0.9844
# Epoch 107/125
# 26/26 [==============================] - 130s 5s/step - loss: 0.4658 - accuracy: 0.7921 - val_loss: 0.6564 - val_accuracy: 0.6094
# Epoch 108/125
# 26/26 [==============================] - 124s 5s/step - loss: 0.3905 - accuracy: 0.8564 - val_loss: 0.1921 - val_accuracy: 0.9792
# Epoch 109/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.3616 - accuracy: 0.8812 - val_loss: 0.7881 - val_accuracy: 0.5938
# Epoch 110/125
# 26/26 [==============================] - 124s 5s/step - loss: 0.5006 - accuracy: 0.8181 - val_loss: 0.2082 - val_accuracy: 0.9740
# Epoch 111/125
# 26/26 [==============================] - 113s 4s/step - loss: 0.6728 - accuracy: 0.8478 - val_loss: 0.1730 - val_accuracy: 0.9792
# Epoch 112/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.3225 - accuracy: 0.9270 - val_loss: 1.4291 - val_accuracy: 0.4271
# Epoch 113/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.3572 - accuracy: 0.8663 - val_loss: 0.2398 - val_accuracy: 0.8854
# Epoch 114/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.4784 - accuracy: 0.8317 - val_loss: 0.1612 - val_accuracy: 0.9740
# Epoch 115/125
# 26/26 [==============================] - 110s 4s/step - loss: 0.4000 - accuracy: 0.8465 - val_loss: 0.1456 - val_accuracy: 0.9688
# Epoch 116/125
# 26/26 [==============================] - 111s 4s/step - loss: 0.3211 - accuracy: 0.8750 - val_loss: 0.2077 - val_accuracy: 0.9479
# Epoch 117/125
# 26/26 [==============================] - 108s 4s/step - loss: 0.8982 - accuracy: 0.9209 - val_loss: 0.1651 - val_accuracy: 0.9531
# Epoch 118/125
# 26/26 [==============================] - 109s 4s/step - loss: 0.3175 - accuracy: 0.8738 - val_loss: 0.2591 - val_accuracy: 0.8750
# Epoch 119/125
# 26/26 [==============================] - 112s 4s/step - loss: 0.4316 - accuracy: 0.8257 - val_loss: 1.2640 - val_accuracy: 0.5208
# Epoch 120/125
# 26/26 [==============================] - 107s 4s/step - loss: 0.5416 - accuracy: 0.7857 - val_loss: 0.6259 - val_accuracy: 0.8229
# Epoch 121/125
# 26/26 [==============================] - 109s 4s/step - loss: 0.3783 - accuracy: 0.8700 - val_loss: 0.2873 - val_accuracy: 0.8698
# Epoch 122/125
# 26/26 [==============================] - 121s 5s/step - loss: 0.2864 - accuracy: 0.8948 - val_loss: 0.2434 - val_accuracy: 0.8958
# Epoch 123/125
# 26/26 [==============================] - 119s 5s/step - loss: 0.3608 - accuracy: 0.8642 - val_loss: 0.1809 - val_accuracy: 0.9844
# Epoch 124/125
# 26/26 [==============================] - 108s 4s/step - loss: 0.4135 - accuracy: 0.8837 - val_loss: 0.2282 - val_accuracy: 0.9062
# Epoch 125/125
# 26/26 [==============================] - 106s 4s/step - loss: 0.3181 - accuracy: 0.9018 - val_loss: 0.4988 - val_accuracy: 0.6927

# %%
model.save('/Users/anranxu/Desktop/3_layers_averagepooling_125_epochs.h5')

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# plt.plot(epochs, acc, 'r', label='Training accuracy')
# plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
# plt.title('Training and validation accuracy')
# plt.legend(loc=0)
# plt.figure()


# plt.show()
plt.figure()
plt.plot( epochs,     acc )
plt.plot( epochs, val_acc )
plt.title('Training and validation accuracy')
plt.savefig('/Users/anranxu/Desktop/Training and validation accuracy(2).jpg')
plt.figure()
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss' )
plt.savefig('/Users/anranxu/Desktop/Training and validation loss(2).jpg')

# %%
img = load_img('/Users/anranxu/Desktop/ML/training/0.3/0.3(1)_(91,96).jpg', color_mode="grayscale")
img_array = img_to_array(img)
img_array = tf.expand_dims(img_array/255, 0)
classes = model.predict_classes(img_array)
print(classes)
# Out:
# [2]

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
loaded_model = load_model('/Users/anranxu/Desktop/3_layers_averagepooling_125_epochs.h5')
img = load_img('/Users/anranxu/Desktop/ML/training/0.3/0.3(1)_(91,96).jpg', color_mode="grayscale")
img_array = img_to_array(img)
img_array = tf.expand_dims(img_array/255, 0)
classes = loaded_model.predict_classes(img_array)
print(classes)
# Out:
# [2]

# %%
import tensorflow as tf
ACCURACY_THRESHOLD = 0.97

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > ACCURACY_THRESHOLD):
            print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
            self.model.stop_training = True

# Instantiate a callback object
callbacks = myCallback()

# %%
model.summary()
# optimizer = tf.keras.optimizers.SGD(lr=8e-4, momentum=0.6)

model.compile(loss = 'categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

history = model.fit(train_generator, epochs=200, steps_per_epoch=840//32, validation_data = validation_generator, verbose = 1, validation_steps=200//32, callbacks =[callbacks])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 502, 502, 16)      160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 251, 251, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 249, 249, 32)      4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 124, 124, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 122, 122, 64)      18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 61, 61, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 238144)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               121930240
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 121,958,666
# Trainable params: 121,958,666
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 26/26 [==============================] - 87s 3s/step - loss: 3.3652 - accuracy: 0.1200 - val_loss: 2.3016 - val_accuracy: 0.1146
# Epoch 2/200
# 26/26 [==============================] - 87s 3s/step - loss: 2.3028 - accuracy: 0.1052 - val_loss: 2.3025 - val_accuracy: 0.1042
# Epoch 3/200
# 26/26 [==============================] - 87s 3s/step - loss: 2.3030 - accuracy: 0.1015 - val_loss: 2.3024 - val_accuracy: 0.1042
# Epoch 4/200
# 26/26 [==============================] - 90s 3s/step - loss: 2.3028 - accuracy: 0.0879 - val_loss: 2.3026 - val_accuracy: 0.1042
# Epoch 5/200
# 26/26 [==============================] - 266s 10s/step - loss: 2.3028 - accuracy: 0.1027 - val_loss: 2.3026 - val_accuracy: 0.1042
# Epoch 6/200
# 26/26 [==============================] - 120s 5s/step - loss: 2.3030 - accuracy: 0.0865 - val_loss: 2.3026 - val_accuracy: 0.1042
# Epoch 7/200
# 26/26 [==============================] - 121s 5s/step - loss: 2.3029 - accuracy: 0.0918 - val_loss: 2.3026 - val_accuracy: 0.1042
# Epoch 8/200
# 26/26 [==============================] - 141s 5s/step - loss: 2.3028 - accuracy: 0.1010 - val_loss: 2.3025 - val_accuracy: 0.1042
# Epoch 9/200
# 24/26 [==========================>...] - ETA: 7s - loss: 2.3026 - accuracy: 0.1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-21861b46fae7> in <module>
#       4 model.compile(loss = 'categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
#       5
# ----> 6 history = model.fit(train_generator, epochs=200, steps_per_epoch=840//32, validation_data = validation_generator, verbose = 1, validation_steps=200//32, callbacks =[callbacks])
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     768           use_multiprocessing=use_multiprocessing,
#     769           shuffle=shuffle,
# --> 770           initial_epoch=initial_epoch)
#     771     if training_utils.is_eager_dataset_or_iterator(x):
#     772       # Make sure that y, sample_weights, validation_split are not passed.
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1513         shuffle=shuffle,
#    1514         initial_epoch=initial_epoch,
# -> 1515         steps_name='steps_per_epoch')
#    1516
#    1517   def evaluate_generator(self,
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     255
#     256       is_deferred = not model._is_compiled
# --> 257       batch_outs = batch_function(*batch_data)
#     258       if not isinstance(batch_outs, list):
#     259         batch_outs = [batch_outs]
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1257       else:
#    1258         self._make_fit_function()
# -> 1259         outputs = self._fit_function(ins)  # pylint: disable=not-callable
#    1260
#    1261     if reset_metrics:
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3215         value = math_ops.cast(value, tensor.dtype)
#    3216       converted_inputs.append(value)
# -> 3217     outputs = self._graph_fn(*converted_inputs)
#    3218     return nest.pack_sequence_as(self._outputs_structure,
#    3219                                  [x.numpy() for x in outputs])
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#     556       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     557           list(kwargs.keys()), list(self._arg_keywords)))
# --> 558     return self._call_flat(args)
#     559
#     560   def _filtered_call(self, args, kwargs):
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args)
#     625     # Only need to override the gradient in graph mode and when we have outputs.
#     626     if context.executing_eagerly() or not self.outputs:
# --> 627       outputs = self._inference_function.call(ctx, args)
#     628     else:
#     629       self._register_gradient()
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args)
#     413             attrs=("executor_type", executor_type,
#     414                    "config_proto", config),
# --> 415             ctx=ctx)
#     416       # Replace empty list with None
#     417       outputs = outputs or None
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      59                                                op_name, inputs, attrs,
# ---> 60                                                num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
